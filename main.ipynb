# %%
# %matplotlib inline
from plot_nutrition import plot_nutrition
from plot_wordcloud import plot_wordcloud
from plot_popularity import get_food_popularity_graph
from plot_cooktime import get_cooking_time_graph
from plot_polar import polar_plot
from plot_choropleth import geoplot
from scrapeURL import scrapeURL
from scrape import scrape

import bokeh.io

bokeh.io.output_notebook()
# Out:
# [nltk_data] Downloading package wordnet to /Users/utkarsh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Run scraping scripts
#
# ## Scrape URL lists
#
# Example:
# ``` Python3
# scrapeURL('https://www.allrecipes.com/recipes/17138/world-cuisine/european/french/main-dishes/?page=', 9, 'url_France.pkl')
# ```

# %%
scrapeURL(root_url = 'https://www.allrecipes.com/recipes/17138/world-cuisine/european/french/main-dishes/?page=', 
          num_pages = 9, 
          save_path = './data/url_France.pkl')
# Out:
# 100%|██████████| 9/9 [00:14<00:00,  1.50s/it]

# %% [markdown]
# ## Scrape recipes
#
# Example:
# ``` Python3
# scrape('./data/url_France.pkl', save_path = './data/allrecipes_France.pkl')
# ```

# %% [markdown]
# scrape('./data/url_France.pkl', save_path = './data/allrecipes_France.pkl')

# %% [markdown]
# # Country Names
#
# Country names should be in one of the following:
#
# ``` Python3
# 'China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US'
# ```

# %% [markdown]
# # Plot Nutrition Facts v.s. Obesity Rate
#
# Create `plot_nutrition` obeject

# %%
n = plot_nutrition()

# %% [markdown]
# ## Plot Bars And Lines
#
# Plot bars for obesity rate, and lines for nutrition facts.
#
# Example:
#
# ``` Python3
# n.plot_bar_line(save_path='./img/bar.html')
# ```

# %%
n.plot_bar_line(save_path='./img/bar.html')
# Out:
#   <div class="bk-root" id="26a2a6af-2317-415d-82aa-67d4f872df18" data-root-id="1344"></div>

# %% [markdown]
# ## Plot Scatter Plots
#
# Plot scatter plots of the data, with $x$-axis as its obesity rate, and $y$-axis as its nutrition facts
#
# Example:
#
# ``` Python3
# n.plot_scatter(save_path='./img/lr.html')
# ```

# %%
n.plot_scatter(save_path='./img/lr.html')
# Out:
#   <div class="bk-root" id="64a60c98-0a23-455a-9b41-f5a4d3cc587d" data-root-id="2752"></div>

# %% [markdown]
# # Plot Ingredient Wordcloud
#
# Create `plot_wordcloud` object
#
# Example:
#
# ```
# wc = plot_wordcloud('Thai')
# wc = plot_wordcloud('India')
# ...
# ```

# %%
wc = plot_wordcloud('Italy')

# %% [markdown]
# ## Plot Wordcloud
#
# Plot wordcloud according to the frequencies of ingredients
#
# Example:
#
# ``` Python3
# wc.plot_wordcloud(background = './img/Thai.png', save_path = './img/wc_Thai.png', log_scale = True)
# wc.plot_wordcloud(background = './img/India.png', save_path = './img/wc_India.png', log_scale = True)
# ...
# ```

# %%
wc.plot_wordcloud(background = './img/Italy.png', save_path = './img/wc_Italy.png', log_scale = True)
# Out:
# /Users/utkarsh/anaconda2/envs/python-3.7/lib/python3.7/site-packages/PIL/Image.py:968: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +

# %% [markdown]
# # Plot Ratings
#
# We crawled data for 10 countries `'China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US'`.
#
# Example:
#
# ``` Python3
# countries = ['China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US']
# get_food_popularity_graph(countries)
# ```

# %%
countries = ['China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US']
get_food_popularity_graph(countries)

# %% [markdown]
# # Plot Cooking time
#
# We crawled data for 10 countries `'China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US'`.
#
# Example:
#
# ``` Python3
# countries = ['China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US']
# get_cooking_time_graph(countries)
# ```

# %%
countries = ['China','France','Greece','India','Italy','Japan','Korea','Mexico','Thai','US']
get_cooking_time_graph(countries)

# %% [markdown]
# # Plot Ingredient Frequency v.s. Product Consumption
#
# Plot
#
# Example:
#
# ``` Python3
# polar_plot('India')
# polar_plot('Thai')
# ...
# ```

# %%
polar_plot('India')

# %% [markdown]
# # Plot Geo Plot of obesity rate
#
# Example:
#
# ``` Python3
# geoplot()
# ```

# %%
geoplot()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3690">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="34b9a51c-88c7-4411-9ddb-ea347458bbe0" data-root-id="3651"></div>
